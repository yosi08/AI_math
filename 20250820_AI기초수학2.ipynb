# %% [markdown]
# ---
# #1. LaTeX(레이텍)이란?
#
# - LaTeX는 문서 조판 시스템으로 복잡한 수식, 표 등을 정확하고 예쁘게 표현할 수 있는 고급 텍스트 문서 작성 도구
# - Markdown 문서에서 수학 기호와 표현을 위해 LaTeX 수식을 사용

# %% [markdown]
# #### 두개의 $를 시작과 끝에 겹쳐서 다항식 표현, 문장 속에 latex식이 일부 들어가게 하려면 두번 겹치지 않고 하나씩

# %% [markdown]
# 수식 $y=2x+1$ 입니다.

# %% [markdown]
# ---
# 수식 $$y=2x+1$$ 입니다.

# %% [markdown]
# ---
# ### 윗 첨자(^)와 아래 첨자(_)

# %% [markdown]
# $$y_{(ij)^5} = x^3 + 4x^2 + x - 3$$

# %% [markdown]
# ---
# ### 기본 기호
# 제곱근(\sqrt)
#
# 삼각함수(\sin, \cos, \tan)
#
# 분수(\frac{분자}{분모})
#
# 합계(\sum), 누적곱(\prod), 곱셈의 가운데 점(\cdot)

# %% [markdown]
# $$ y = \sqrt{(y-y_i)^2} $$

# %% [markdown]
# $$ \sin^2x + \cos^2y = 1 $$

# %% [markdown]
# $$ y = \frac{1}{\tan x} $$

# %% [markdown]
# $$ y = \sum_{k=1}^n k $$

# %% [markdown]
# $$ y = \prod_{k=1}^n x_k $$

# %% [markdown]
# ---
# ### 그리스 문자
# α: \alpha
# β: \beta
# γ: \gamma
# δ: \delta
# ϵ: \epsilon
#
# θ: \theta
# λ: \lambda
# μ: \mu
# π: \pi
# ρ: \rho
# σ: \sigma
# ϕ: \phi

# %% [markdown]
# ---
# ### 대문자 그리스 문자
# Γ: \Gamma
# Δ: \Delta
# Λ: \Lambda
# Π: \Pi
# Σ: \Sigma
# Υ: \Upsilon
# Φ: \Phi
# Ψ: \Psi
# Ω: \Omega

# %% [markdown]
# ####저항을 계산하는 공식은: $$R = \rho \frac{L}{A}$$

# %% [markdown]
# ---
# ## 집합관련
#   원소 속함 : \in
#   원소 속하지 않음 : \notin
#
#   부분집합 : (포함된다) \subset, \subseteq (포함한다)\supset, \supseteq
#   부분집합 아님 : \not\subset, \not\setseteq
#
#    공집합 : \emptyset, \varnothing
#    전체집합 : \mathcal{U}
#    합집합 : \cup
#    교집합 : \cap
#    여집합 : A^c, A^C, \bar{A}
#    곱집합 : \times
#
#    집합기호 : \{, \}
#    크기조절 가능한 집합 기호: \left\{, \right\}
#
#    특수집합 : (자연수) \mathbb{N}, (정수) \mathbb{Z}, (유리수) \mathbb{Q}, (실수) \mathbb{R}, (복소수) \mathbb{C}

# %% [markdown]
# ---
# # <퀴즈> 다음 문장을 LaTeX로 작성하세요.

# %% [markdown]
# ---
# ## (문1) 원의 둘레는 2πr이고, 면적은 πr2 입니다.

# %% [markdown]
# 원의 둘레는 $2\pi r$이고, 면적은 $\pi r^2$입니다.

# %% [markdown]
# ---
# ## (문2) ΔE=mc^2 (여기서 Δ는 에너지 변화, m은 질량, c는 빛의 속도입니다.)

# %% [markdown]
# $$
# \Delta E = mc^2
# $$

# %% [markdown]
# ---
# ## (문3) 베이즈 정리 유도 과정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $$
# P(A \mid B) = \frac{P(A \cap B)}{P(B)} = \frac{P(B \mid A) \cdot P(A)}{P(B)}
# $$

# %% [markdown]
# 인공지능에서 가장 기초가 되는 내용 -> 분류(강아지,고양이)
#
# 가장 핵심적인 알고리즘
#
# 사전 확률을 바탕으로 사후 확률을 계산하는 방법

# %% [markdown]
# ---
# ## 행렬의 표현
# pmatrix (소괄호)
#
# bmatrix (대괄호)
#
# vmatrix (수직선)

# %% [markdown]
# ---
# ## 행렬의 요소 생략
# \dots : 수평 생략
# \vdots : 수직 생략
# \ddots : 대각선 생략
#
# ---

# %% [markdown]
# $$\begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}$$

# %% [markdown]
# $$\begin{bmatrix}
# 1 & 2 & 3
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# 4 \\
# 5 \\
# 6
# \end{bmatrix}$$

# %% [markdown]
# $$\begin{bmatrix}
# 1 \\
# 2 \\
# \vdots \\
# n
# \end{bmatrix}$$

# %% [markdown]
# $$\begin{bmatrix}
# a_{11} & 0 & \cdots & 0 \\
# 0 & a_{22} & \cdots & 0 \\
# \vdots & \vdots & \ddots & \vdots \\
# 0 & 0 & \cdots & a_{nn}
# \end{bmatrix}$$

# %% [markdown]
# $$\vec{a} \cdot \vec{b} = |a||b|\cos{\theta}$$

# %% [markdown]
# ---
# # (과제) 다음은 고1 수학의 공식들을 정리한 블로그 이다. 이중 하나를 선택해서 Latex으로 작성해보세요.
# [고1수학 공식](https://mrkimminho.tistory.com/entry/%EC%88%98%ED%95%99%EC%83%81-%EA%B3%A01-%EC%88%98%ED%95%99-%EA%B0%9C%EB%85%90%EC%A0%95%EB%A6%AC-%EA%B3%B5%EC%8B%9D%EB%AA%A8%EC%9D%8C-%EB%B0%94%EB%A1%9C%EB%B3%B4%EA%B8%B0-%EA%B3%B5%EC%8B%9D%EC%9D%84-%EC%95%94%EA%B8%B0%ED%95%98%EC%A7%80-%EC%95%8A%EA%B3%A0-%EC%9D%B4%ED%95%B4%ED%95%98%EB%8A%94-%EB%B2%95-feat%EC%9E%A0%EC%8B%A0%EA%B3%A01-%EC%88%98%ED%95%99%EC%84%B1%EC%A0%81-%ED%96%A5%EC%83%81-%EC%82%AC%EB%A1%80)

# %% [markdown]
#  기본 사용법
#  인라인 수식
#
# 문장 중간에 수식 삽입: $
#
# 이차방정식의 해는 $x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$ 이다.
#
#  블록 수식
#
# 중앙 정렬 수식: $$
#
# $$
# f(x) = \int_{a}^{b} x^2 dx
# $$
